# %%
# IMPORT STATEMENTS
import sys
sys.path.append("/booleanfs2/sahoo/Hegemon/")
sys.path = ["/booleanfs2/sahoo/BoNE/"] + sys.path

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3
        
import SMaRT.MacUtils as mut
reload(mut)
# Out:
# <module 'SMaRT.MacUtils' from '/booleanfs2/sahoo/BoNE/SMaRT/MacUtils.py'>

# %%
import pandas as pd
import numpy as np
import bone
reload(bone)
import Datasets
reload(Datasets)
import Datasets_hh
reload(Datasets_hh)
hu = bone.hu

# %% [markdown]
# # Figure 4

# %%
wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getVanneste2023(2) # GSE194021
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getSandra_IPT_2024(1) # GSE277297
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getSandra2024(1) # GSE243289
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getSajti2020BL6DBA(2) # GSE136916
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getSajti2020(2) # GSE136914
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getJakubzick2017(1) # GSE94135
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)

wt1, l1 = mut.getCls13()
l1 = mut.getGroupsMm(l1)
ana = bone.IBDAnalysis()
ana.getStefan2023(1) # GSE235136
fig = bone.processData(ana, l1, wt1, desc=None, violin=1)
# Out:
# Vanneste 2023 lung im mac mm (n = 18)
# GSE194021 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=BL34
# 15 [12, 3] GSE194021 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=BL34 BL34
# [68]
# Sandra_IPT 2024 [mm lung] (n = 24)
# GSE277297 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T124
# 16 [8, 8] GSE277297 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T124 T124
# [52]
# Sandra 2024 [mm lung] (n = 15)
# GSE243289 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T123
# 10 [5, 5] GSE243289 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T123 T123
# [52]
# Sajti 2020 mac Mm BL6 DBA (n = 16)
# GSE137068 GSE136916 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV96.3
# 8 [4, 4] GSE137068 GSE136916 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV96.3 MACV96.3
# [65]
# Sajti 2020 mac Mm (n = 45)
# GSE136914 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV96
# 31 [14, 17] GSE136914 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV96 MACV96
# [65]
# Jakubzick 2017 [mm lung] (n = 12)
# GSE94135 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T121
# 12 [9, 3] GSE94135 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T121 T121
# [65]
# Stefan 2023 [mm lung] (n = 6)
# GSE235136 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T122
# 6 [3, 3] GSE235136 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=T122 T122
# [65]
